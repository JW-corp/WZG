# %%
unc_source = "aQGC_card_SR_mlllA_bin2.txt"

# %%
import pandas as pd

# %%
df = pd.read_csv(unc_source, sep='\s+')
df
# Out:
#             process type  aQGC_ch1 VG_ch1 VVV_ch1   Top_ch1 FakePho_ch1  \
# 0   FakePho_closure  lnN         -      -       -         -    1.080397
# 1       FakePho_iso  lnN         -      -       -         -    1.022293
# 2        FakePho_mc  lnN         -      -       -         -    1.012835
# 3    FakePho_sta_16  lnN         -      -       -         -    1.015722
# 4    FakePho_sta_17  lnN         -      -       -         -           -
# ..              ...  ...       ...    ...     ...       ...         ...
# 74          lumi_18  lnN         -      -       -         -           -
# 75    lumi_fullrun2  lnN     1.006  1.006   1.006     1.006           -
# 76          muon_id  lnN   1.00458    1.0     1.0  1.001886           -
# 77        photon_id  lnN  1.022999    1.0     1.0  1.022622           -
# 78           pileup  lnN  1.010733    1.0     1.0  1.082796           -
#
#       VV_ch1 FakeLep_ch1  aQGC_ch2  ... FakePho_ch2    VV_ch2 FakeLep_ch2  \
# 0          -           -         -  ...    1.253214         -           -
# 1          -           -         -  ...    1.001269         -           -
# 2          -           -         -  ...     1.03215         -           -
# 3          -           -         -  ...           -         -           -
# 4          -           -         -  ...    1.013096         -           -
# ..       ...         ...       ...  ...         ...       ...         ...
# 74         -           -         -  ...           -         -           -
# 75     1.006           -     1.009  ...       1.009     1.009           -
# 76  1.006008           -  1.002811  ...           -  1.002576           -
# 77  1.022011           -  1.025838  ...           -  1.022285           -
# 78  1.071594           -   1.01131  ...           -  1.067057           -
#
#     aQGC_ch3 VG_ch3   VVV_ch3   Top_ch3 FakePho_ch3    VV_ch3 FakeLep_ch3
# 0          -      -         -         -    1.059731         -           -
# 1          -      -         -         -    1.002464         -           -
# 2          -      -         -         -    1.036132         -           -
# 3          -      -         -         -           -         -           -
# 4          -      -         -         -           -         -           -
# ..       ...    ...       ...       ...         ...       ...         ...
# 74     1.015  1.015     1.015     1.015       1.015     1.015           -
# 75      1.02   1.02      1.02      1.02        1.02      1.02           -
# 76  1.001618    1.0   1.00195  1.002416           -  1.001437           -
# 77  1.022128    1.0  1.019681  1.008997           -  1.020124           -
# 78  1.018375    1.0  1.006426  1.016034           -   1.02268           -
#
# [79 rows x 23 columns]

# %%
df.set_index('process',inplace=True)

# %%
df.drop(columns=['type'],inplace=True)

# %%
df = df.apply(pd.to_numeric, errors='coerce')

# %%
with open('Unc_summary.csv', 'w') as f:
    f.write('Uncertainty, Min, Max, Min(%), Max(%)\n')
    for uncname in df.index:
        idxmin=df.loc[uncname].idxmin()
        uncmin=(df.loc[uncname].min() -1)*100
        idxmax=df.loc[uncname].idxmax()
        uncmax=(df.loc[uncname].max() -1)*100
        print(f"{uncname} : {idxmin} ,  {idxmax},  {uncmin:.3f} , {uncmax:.3f}")
        f.write(f"{uncname} , {idxmin} ,  {idxmax},  {uncmin:.3f} , {uncmax:.3f}\n")
# Out:
# FakePho_closure : FakePho_ch3 ,  FakePho_ch2,  5.973 , 25.321
# FakePho_iso : FakePho_ch2 ,  FakePho_ch1,  0.127 , 2.229
# FakePho_mc : FakePho_ch1 ,  FakePho_ch3,  1.283 , 3.613
# FakePho_sta_16 : FakePho_ch1 ,  FakePho_ch1,  1.572 , 1.572
# FakePho_sta_17 : FakePho_ch2 ,  FakePho_ch2,  1.310 , 1.310
# FakePho_sta_18 : FakePho_ch3 ,  FakePho_ch3,  24.700 , 24.700
# HLT_method_sys : aQGC_ch1 ,  aQGC_ch1,  1.000 , 1.000
# HLT_sta_18 : aQGC_ch3 ,  aQGC_ch3,  0.200 , 0.200
# SR_FakeLep_stat_16_bin2 : FakeLep_ch1 ,  FakeLep_ch1,  73.179 , 73.179
# SR_FakeLep_stat_17_bin2 : FakeLep_ch2 ,  FakeLep_ch2,  125.619 , 125.619
# SR_FakeLep_stat_18_bin2 : FakeLep_ch3 ,  FakeLep_ch3,  112.807 , 112.807
# SR_FakePho_stat_16_bin2 : FakePho_ch1 ,  FakePho_ch1,  114.607 , 114.607
# SR_FakePho_stat_17_bin2 : FakePho_ch2 ,  FakePho_ch2,  112.659 , 112.659
# SR_FakePho_stat_18_bin2 : FakePho_ch3 ,  FakePho_ch3,  118.453 , 118.453
# SR_HLT_stat_16_bin2 : aQGC_ch1 ,  aQGC_ch1,  0.300 , 0.300
# SR_HLT_stat_17_bin2 : aQGC_ch2 ,  aQGC_ch2,  0.300 , 0.300
# SR_Top_stat_16_bin2 : Top_ch1 ,  Top_ch1,  58.636 , 58.636
# SR_Top_stat_17_bin2 : Top_ch2 ,  Top_ch2,  18.947 , 18.947
# SR_Top_stat_18_bin2 : Top_ch3 ,  Top_ch3,  47.404 , 47.404
# SR_VG_stat_17_bin2 : VG_ch2 ,  VG_ch2,  100.000 , 100.000
# SR_VVV_stat_17_bin2 : VVV_ch2 ,  VVV_ch2,  100.000 , 100.000
# SR_VVV_stat_18_bin2 : VVV_ch3 ,  VVV_ch3,  15.066 , 15.066
# SR_VV_stat_16_bin2 : VV_ch1 ,  VV_ch1,  10.997 , 10.997
# SR_VV_stat_17_bin2 : VV_ch2 ,  VV_ch2,  8.673 , 8.673
# SR_VV_stat_18_bin2 : VV_ch3 ,  VV_ch3,  8.282 , 8.282
# SR_aQGC_stat_16_bin2 : aQGC_ch1 ,  aQGC_ch1,  9.451 , 9.451
# SR_aQGC_stat_17_bin2 : aQGC_ch2 ,  aQGC_ch2,  8.401 , 8.401
# SR_aQGC_stat_18_bin2 : aQGC_ch3 ,  aQGC_ch3,  8.625 , 8.625
# Top_PSWeight_fsr : Top_ch1 ,  Top_ch2,  24.314 , 81.993
# Top_PSWeight_isr : Top_ch3 ,  Top_ch2,  7.706 , 13.534
# Top_pdf : Top_ch3 ,  Top_ch1,  15.509 , 114.373
# Top_scale : Top_ch3 ,  Top_ch2,  10.963 , 24.745
# VG_PSWeight_fsr : VG_ch2 ,  VG_ch2,  26.819 , 26.819
# VG_PSWeight_isr : VG_ch2 ,  VG_ch2,  7.431 , 7.431
# VG_pdf : VG_ch2 ,  VG_ch2,  2.958 , 2.958
# VG_scale : VG_ch2 ,  VG_ch2,  25.354 , 25.354
# VVV_PSWeight_fsr : VVV_ch3 ,  VVV_ch2,  37.586 , 85.248
# VVV_PSWeight_isr : VVV_ch3 ,  VVV_ch2,  8.638 , 11.902
# VVV_pdf : VVV_ch2 ,  VVV_ch3,  2.385 , 4.769
# VVV_scale : VVV_ch3 ,  VVV_ch2,  12.681 , 22.656
# VV_PSWeight_fsr : VV_ch3 ,  VV_ch1,  28.877 , 31.177
# VV_PSWeight_isr : VV_ch2 ,  VV_ch1,  7.794 , 9.161
# VV_pdf : VV_ch3 ,  VV_ch1,  3.464 , 4.245
# VV_scale : VV_ch1 ,  VV_ch2,  3.055 , 3.308
# WZG_PSWeight_fsr : aQGC_ch1 ,  aQGC_ch2,  1.302 , 8.613
# WZG_PSWeight_isr : aQGC_ch3 ,  aQGC_ch1,  0.431 , 0.887
# WZG_pdf : aQGC_ch1 ,  aQGC_ch3,  4.758 , 6.866
# WZG_scale : aQGC_ch2 ,  aQGC_ch3,  7.824 , 8.506
# btagWeight_bc_corr : VG_ch1 ,  VVV_ch2,  0.000 , 0.549
# btagWeight_bc_uncorr_16 : VG_ch1 ,  Top_ch1,  0.000 , 0.102
# btagWeight_bc_uncorr_17 : VG_ch2 ,  VVV_ch2,  0.000 , 0.549
# btagWeight_bc_uncorr_18 : VG_ch3 ,  Top_ch3,  0.000 , 0.220
# btagWeight_l_corr : VG_ch1 ,  Top_ch3,  0.000 , 179.743
# btagWeight_l_uncorr_16 : VG_ch1 ,  Top_ch1,  0.000 , 152.974
# btagWeight_l_uncorr_17 : VG_ch2 ,  Top_ch2,  0.000 , 28.571
# btagWeight_l_uncorr_18 : VG_ch3 ,  Top_ch3,  0.000 , 179.706
# ele_id : VG_ch1 ,  VG_ch2,  0.000 , 100.472
# ele_reco : VG_ch1 ,  VG_ch2,  0.000 , 4.792
# fakerate_16 : FakeLep_ch1 ,  FakeLep_ch1,  11.212 , 11.212
# fakerate_16Sys : FakeLep_ch1 ,  FakeLep_ch1,  11.212 , 11.212
# fakerate_17 : FakeLep_ch2 ,  FakeLep_ch2,  10.481 , 10.481
# fakerate_17Sys : FakeLep_ch2 ,  FakeLep_ch2,  10.481 , 10.481
# fakerate_18 : FakeLep_ch3 ,  FakeLep_ch3,  5.108 , 5.108
# fakerate_18Sys : FakeLep_ch3 ,  FakeLep_ch3,  5.108 , 5.108
# jer_16 : VG_ch1 ,  VV_ch1,  0.000 , 3.442
# jer_17 : VG_ch2 ,  Top_ch2,  0.000 , 2.680
# jer_18 : VG_ch3 ,  Top_ch3,  0.000 , 5.724
# jesTotal_16 : VG_ch1 ,  VV_ch1,  0.000 , 1.547
# jesTotal_17 : VG_ch2 ,  VVV_ch2,  0.000 , 85.336
# jesTotal_18 : VG_ch3 ,  Top_ch3,  0.000 , 11.040
# l1pref : VG_ch1 ,  Top_ch2,  0.000 , 1.941
# lumi_16 : aQGC_ch1 ,  aQGC_ch1,  1.000 , 1.000
# lumi_17 : aQGC_ch2 ,  aQGC_ch2,  2.000 , 2.000
# lumi_1718 : aQGC_ch3 ,  aQGC_ch2,  0.200 , 0.600
# lumi_18 : aQGC_ch3 ,  aQGC_ch3,  1.500 , 1.500
# lumi_fullrun2 : aQGC_ch1 ,  aQGC_ch3,  0.600 , 2.000
# muon_id : VG_ch1 ,  VV_ch1,  0.000 , 0.601
# photon_id : VG_ch1 ,  Top_ch2,  0.000 , 4.648
# pileup : VG_ch1 ,  VG_ch2,  0.000 , 13.608

# %%
df.loc['FakePho_closure'].idxmin()
# Out:
# 'FakePho_ch3'
